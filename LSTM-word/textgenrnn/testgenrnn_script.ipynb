# %%
from textgenrnn import textgenrnn
import os
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/tennisonyu/anaconda3/envs/w266-lstm/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
textgen = textgenrnn()
textgen.train_from_largetext_file('train_sentence_split.txt',new_model=True,num_epochs=50,word_level=True, max_length=80)
textgen.generate()
# Out:
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 1,567,718 word sequences.
# Epoch 1/50
# 12247/12247 [==============================] - 269s 22ms/step - loss: 5.0906
# ####################
# Temperature: 0.2
# ####################
#
#  .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# and , yes , we are going to be a model .
# the united states will be a model .
# the united states will not be a model of the united states .
# the united states is not a great nation .
# the united states has been a great deal of the united states .
# the soviet union has been agreed to be a model of the united states .
# the united states was signed by the united states of america .
# the united states was signed by the treaty of april 25 , 1859 , and the united states , and the united states of america and the united states of america .
# ...

# %%
textgen.generate(1, prefix="Here worked Lincoln ")
