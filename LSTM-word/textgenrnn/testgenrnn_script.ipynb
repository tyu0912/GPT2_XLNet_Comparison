# %%
from textgenrnn import textgenrnn
import os
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/tennisonyu/anaconda3/envs/w266-lstm/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
textgen = textgenrnn()
textgen.train_from_largetext_file('train_sentence_split.txt',new_model=True,num_epochs=1,word_level=True, max_length=80)
textgen.generate()
# Out:
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 1,567,718 word sequences.
# WARNING:tensorflow:From /home/tennisonyu/anaconda3/envs/w266-lstm/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/1
# 12247/12247 [==============================] - 518s 42ms/step - loss: 5.2779
# ####################
# Temperature: 0.2
# ####################
# a great question of the public service .
# i am not a matter of the public service .
# i am not to be able to take the effect of the executive department .
# i am not to be able to make the public service in the whole country .
# i am not to be able to be the first time of the present session .
# i am not informed that the congress will be a great question of the government of the united states .
# i am not to be the first time of the constitution .
# ...

# %%
result = textgen.generate(1, prefix="That is amazing ")
# Out:
# senate and house of representatives by the constitution and question that the constitution would be a state to vote .
# he has been a question of the constitution , and the constitution exclusive privileges of the first state .
# alaska was not only by law .
# the whereas the constitution were made in the next session of congress , i am asking that the congress will 13 , 000 , and the executive branch its own citizens .
# the governor of void , and the operation of the united states to the united states , and the tariff act of august 14 .
# the proclamation issued in the number of persons in the united states , the united states , freely and nebraska , have been declared in relation to the united find a proclamation of law , and the purpose of the ordinance within the territory of the united states .
# ...

# %%
dir(textgen)
# Out:
# ['META_TOKEN',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'config',
#  'default_config',
#  'encode_text_vectors',
#  'generate',
#  'generate_samples',
#  'generate_to_file',
#  'indices_char',
#  'load',
#  'model',
#  'num_classes',
#  'reset',
#  'save',
#  'similarity',
#  'tokenizer',
#  'train_from_file',
#  'train_from_largetext_file',
#  'train_new_model',
#  'train_on_texts',
#  'vocab']
