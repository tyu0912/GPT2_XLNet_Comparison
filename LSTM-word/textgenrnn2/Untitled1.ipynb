# %%
out_there = open("delimtest.txt", "w")
out_there.write(u"input_indexτinput\u0394output\u0394gpt2_tuned\u0394xlnet\u0394lstm_attention\u0394gpt2_untuned_bert\u0394gpt2_untuned\n")
# Out:
# 88

# %%
import sys
sys.getdefaulencoding()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-0a0b24b41627> in <module>
#       1 import sys
# ----> 2 sys.getdefaulencoding()
#
# AttributeError: module 'sys' has no attribute 'getdefaulencoding'
