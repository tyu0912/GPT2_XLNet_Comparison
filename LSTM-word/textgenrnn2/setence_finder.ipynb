# %%
fh = open("LSTM-attention-result-test-fixed-30-epoch.txt","r").read()

# %%
for pack in fh.split("<new_line>"):
    if "Only by saving energy can we maintain our standard of living and keep our people at work" in pack:
        print(pack)
# Out:
# The second principle is that healthy economic growth must continue.<entry>Only by saving energy can we maintain our standard of living and keep our people at work.<entry>We cannot afford to be up.<end_line>
# Only by saving energy can we maintain our standard of living and keep our people at work.<entry>An effective conservation program will create hundreds of thousands of new jobs.<entry>It is not between liberals and conservatives.<end_line>
# The second principle is that healthy economic growth must continue.<entry>Only by saving energy can we maintain our standard of living and keep our people at work.<entry>The challenge for these ends.<end_line>
# Only by saving energy can we maintain our standard of living and keep our people at work.<entry>An effective conservation program will create hundreds of thousands of new jobs.<entry>A nation that should be today without means of constitutional duty.<end_line>
