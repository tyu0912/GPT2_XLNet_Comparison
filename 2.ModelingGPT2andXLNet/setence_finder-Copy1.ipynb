# %%
fh = open("LSTM-attention-result-test-fixed-30-epoch.txt","r").read()

# %%
for pack in fh.split("<new_line>"):
    if "Only by saving energy can we maintain our standard of living and keep our people at work" in pack:
        print(pack)
# Out:
# The second principle is that healthy economic growth must continue.<entry>Only by saving energy can we maintain our standard of living and keep our people at work.<entry>We cannot afford to be up.<end_line>
# Only by saving energy can we maintain our standard of living and keep our people at work.<entry>An effective conservation program will create hundreds of thousands of new jobs.<entry>It is not between liberals and conservatives.<end_line>
# The second principle is that healthy economic growth must continue.<entry>Only by saving energy can we maintain our standard of living and keep our people at work.<entry>The challenge for these ends.<end_line>
# Only by saving energy can we maintain our standard of living and keep our people at work.<entry>An effective conservation program will create hundreds of thousands of new jobs.<entry>A nation that should be today without means of constitutional duty.<end_line>

# %%
sentence = "One problem has been ever constant , with each succeeding President that we should maintain and strengthen the will of the Nation and other nations for peace."

# %%
fh = open("testing_data_run/combined_data/test_gpt2_results.txt","r").read()

for pack in fh.split("<new_line>"):
    if sentence in pack:
        print(pack)
# Out:
# The problems of our country today crowd for entry here as they have each day for more than 130 years past.<entry>One problem has been ever constant , with each succeeding President that we should maintain and strengthen the will of the Nation and other nations for peace.<entry>"We are a nation that is not a country of the rich.<end_line>
# One problem has been ever constant , with each succeeding President that we should maintain and strengthen the will of the Nation and other nations for peace.<entry>In this room have been taken those reluctant steps which have led our Nation to war and those willing steps which have again led to peace.<entry>The President has made it clear that we will not tolerate the use of force in any way that would threaten the security of our country.<end_line>

# %%
fh = open("testing_data_run/combined_data/test_models_results.txt","r").read()

for pack in fh.split("<new_line>"):
    if sentence in pack:
        print(pack)
# Out:
# The problems of our country today crowd for entry here as they have each day for more than 130 years past.<entry>One problem has been ever constant , with each succeeding President that we should maintain and strengthen the will of the Nation and other nations for peace.<entry>They are not the problem of our country today crowd for entry here as they have each day for more than 130 years past.<end_line>
# One problem has been ever constant , with each succeeding President that we should maintain and strengthen the will of the Nation and other nations for peace.<entry>In this room have been taken those reluctant steps which have led our Nation to war and those willing steps which have again led to peace.<entry>We should maintain and strengthen the will of the Nation and other nations for peace.<end_line>

# %%
fh = open("testing_data_run/combined_data/test_xlnet-base-cased_results.txt","r").read()

for pack in fh.split("<new_line>"):
    if sentence in pack:
        print(pack)
# Out:
# The problems of our country today crowd for entry here as they have each day for more than 130 years past.<entry>One problem has been ever constant , with each succeeding President that we should maintain and strengthen the will of the Nation and other nations for peace.<entry>The problems of our country today crowd for entry here as they have each day for more than 130 years past.<end_line>
# One problem has been ever constant , with each succeeding President that we should maintain and strengthen the will of the Nation and other nations for peace.<entry>In this room have been taken those reluctant steps which have led our Nation to war and those willing steps which have again led to peace.<entry>This is a constant problem, with each succeeding President that we should maintain and strengthen the will of the Nation and other nations for peace.<end_line>
