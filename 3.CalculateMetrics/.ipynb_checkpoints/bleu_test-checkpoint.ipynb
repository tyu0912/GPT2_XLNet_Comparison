# %%
import sys
sys.path.insert(1, '../Metrics')

import nmt.nmt.nmt.scripts.bleu as bleu

bleu.compute_bleu("The mouse was small mice", "I killed that mouse hardcore mouse")
# Out:
# (0.0, [0.125, 0.0, 0.0, 0.0], 1.0, 1.0, 24, 24)
